# %% [markdown]
# # Sentiment Analysis of Twitter Reviews
#
# ### Tasks
# + Text Preprocessing
# + Sentiment Analysis
# + Keyword Extraction
# + Entity Extraction
#
# ### Dataset:
# + TwitterAPI Extracted data of various Telecom companies of UK

# %% [markdown]
# #### Importing Modules

# %%
import pandas as pd
import neattext as nfx
import re

### Hide warnings
import warnings 
warnings.filterwarnings('ignore')

# %%
#LOADING DATA SET

df = pd.read_csv('predicted.csv')

# %%
df.iloc[0:3,:]
# Out:
#                  created_at           id    author_id  \
# 0  2022-03-01T14:24:59.000Z  184833230.0  184833230.0
# 1  2022-03-01T14:20:06.000Z  412154216.0  412154216.0
# 2  2022-03-01T14:16:42.000Z  311957759.0  311957759.0
#
#                                                 text               name  \
# 0  @bt_uk @mikeburnieactor I am having the same p...  Michael Hutchings
# 1  @henrystewartdam @TheresaRegli @McDonalds @Yal...         Preservica
# 2  Why's does the TV listings in my @bt_uk box an...       DennisThynne
#
#            location        username  \
# 0  Bristol, England  mikehutchings9
# 1         Worldwide      Preservica
# 2     County Durham    DennisThynne
#
#                                           clean_text  label  predicted_labels
# 0  i am having the same problem online support bo...     -1                -1
# 1                                       we cant wait     -1                 1
# 2  whys does the tv listings in my box and the pl...     -1                -1

# %% [markdown]
# ### Preprocessing

# %%
df.dropna(inplace=True)
df.isnull().sum()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 347 entries, 0 to 346
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   created_at        347 non-null    object
#  1   id                347 non-null    float64
#  2   author_id         347 non-null    float64
#  3   text              347 non-null    object
#  4   name              347 non-null    object
#  5   location          347 non-null    object
#  6   username          347 non-null    object
#  7   clean_text        347 non-null    object
#  8   label             347 non-null    int64
#  9   predicted_labels  347 non-null    int64
# dtypes: float64(2), int64(2), object(6)
# memory usage: 27.2+ KB

# %% [markdown]
# ## Text Preprocessing
# ### Tasks
# + Remove Mentions / Hashtags
# + Replace "'"(appost) wit relevant word
# + ['remove_emails','remove_emojis',
#  'remove_multiple_spaces','remove_puncts','remove_special_characters',
#  'remove_stopwords','remove_urls','remove_userhandles']

# %% [markdown]
# #### Function to cleanText

# %%
import json
with open('contractions.json','r+') as file :
    contraction_dict = json.load(file)


def _get_contractions(contraction_dict):
    contraction_re = re.compile('(%s)' % '|'.join(contraction_dict.keys()))
    return contraction_dict, contraction_re

contractions, contractions_re = _get_contractions(contraction_dict)

def replace_contractions(text):
    text = text.lower()
    def replace(match):
        return contractions[match.group(0)]
    return contractions_re.sub(replace, text.replace("’","'"))

# Usage
df['text'] = df['text'].apply(replace_contractions)

# %%
# print(df.iloc[2].text.lower())
# clean_txt = replace_contractions(df.iloc[2].text)
# clean_txt

# %%
def cleanTxt(text):
    text = text.lower()
    text = nfx.remove_userhandles(text)
    text = nfx.remove_emojis(text)
    text = nfx.remove_urls(text)
    text = re.sub(r'#',' ',text)
    text = re.sub(r'\n',' ',text)
    text = re.sub(r'&amp','&',text)
    text = nfx.remove_stopwords(text)
    text = nfx.remove_puncts(text)
    text = nfx.remove_special_characters(text)
    text = nfx.remove_numbers(text)
    text = nfx.remove_multiple_spaces(text)
    text = text.strip()
    

    return text

# %%
# sample = df.iloc[345]
# clean_txt = cleanTxt(sample.text)
df['clean2_text'] = df['text'].apply(cleanTxt)
# df['clean_text'] = df['text'].apply(cleanTxt)

# %%
df.keys()
# Out:
# Index(['created_at', 'id', 'author_id', 'text', 'name', 'location', 'username',
#        'clean_text', 'label', 'predicted_labels', 'clean2_text'],
#       dtype='object')

# %%
# print(sample.text)
# print('-------------------------------------------------------')
# print(clean_txt)
# df2 = df[['text','clean2_text','label', 'predicted_labels']]
df2 = df[['text','clean2_text','label']]

# %%
df2.head()
# Out:
#                                                 text  \
# 0  @bt_uk @mikeburnieactor i am having the same p...
# 1  @henrystewartdam @theresaregli @mcdonalds @yal...
# 2  why is does the tv listings in my @bt_uk box a...
# 3  @bill626 @bt_uk try setting it to record quest...
# 4  @bill626 @bt_uk i figured it out it will not r...
#
#                                          clean2_text  label
# 0  problem online support booked engineer likely end     -1
# 1                                               wait     -1
# 2  tv listings box planner actual tv think friday...     -1
# 3       try setting record quest midnight tells goes      1
# 4  figured record stuff midnight recording snooke...     -1

# %%
df2.to_csv('without_appost.csv')

# %%
data =pd.read_csv('without_appost.csv',index_col=0)

# %%
data.head()
# Out:
#                                                 text  \
# 0  @bt_uk @mikeburnieactor i am having the same p...
# 1  @henrystewartdam @theresaregli @mcdonalds @yal...
# 2  why is does the tv listings in my @bt_uk box a...
# 3  @bill626 @bt_uk try setting it to record quest...
# 4  @bill626 @bt_uk i figured it out it will not r...
#
#                                          clean2_text  label
# 0  problem online support booked engineer likely end     -1
# 1                                               wait     -1
# 2  tv listings box planner actual tv think friday...     -1
# 3       try setting record quest midnight tells goes      1
# 4  figured record stuff midnight recording snooke...     -1

# %% [markdown]
# ## Extracting keywords

# %%
import yake

simple_extractor = yake.KeywordExtractor()
def get_keywords(text):
    print(text)
    post_kw = simple_extractor.extract_keywords(text)
    kw_list = []
    for word, number in post_kw:
        kw_list.append(word)
    
    return kw_list

# %%
data['keywords'] = data['clean2_text'].apply(get_keywords)
# Out:
# problem online support booked engineer likely end
# wait
# tv listings box planner actual tv think friday th february lost plot issue
# try setting record quest midnight tells goes
# figured record stuff midnight recording snooker quest ch right exception snooker thing want rec today spot this
# showing march th supposed fix unplugging restarting joy
# fiasco upgrading broadband engineer booked today pm arrived lucky around new router required delivered engineer delivered broadband old router disconnected outside oh dear
# nope shows scheduling problem todays recordings scheduled fixed
# tell simply rebuff complaint tell talk bt attempting provide explanation update nice little system worked zeroaccountability
# customerservice apprentice help develop interpersonal skills knowledge ability help customer whilst studying level apprenticeship find liverpool role gt
# letter confirming massive price hikes month wait finish contract cancel line forced super slow internet glad use starlink connection st century
# gets better better house close it comms contracted supply days space hrs estimated fix went yesterday rd th update goodworkbt
# protect fortunate fine hiking prices way contract going endear bt customers online today better deal currently paying reward loyalty bt prepare lose business
# gonna perfect stdavidsday lunch menu new hq diolch yn fawr noel team cawl served gherkin
# good bts mwc talking multitude topics including g augmented reality ar solutions future sports entertainment more talking ar conference later week expecting greenplanet feature
# seriously excited received letter telling bill going up
# ideas bt tv pro box thinks days future software update date says
# complete update tv boxes testing it update watch live tv dated march
# hey recd engineers wanted download software device secure servers asked confirm bt spam caller hung up sorry offended her pass apols
# day right recordings not wife recording holiday says record today start episode tomorrow
# fixed
# broadband speeds poor day age town fibre exchange
# issues internet winchester days now fellow uni friends house updates going fixed whats going on
# human tell contact human please
# emailed ago heard yet
# understand completely
# nan
# Warning! Exception: object of type 'float' has no len() generated by the following text: 'nan'
# send information send direct message got automated response
# grandparents issue box showing date friday th march guide correct today
# tv channels uk regulated ofcom order remove russia today freeview platform broadcast license need revoked ofcom decide revoke russia todays broadcast license hesitate remove channel immediately
# help neighbours sorted
# hike prices march st halfway contract bb month period too offer great deals new customers underwritten existing ones paying more suffice leaving
# refused contact openreach refused raise complainthe showed care compassion neighbours s means contact outside world
# internet barely worked weeks unable work home unacceptable engineers cane worked clearly issue end routers provided trying contact bt morning
# total disaster moved house feb messed order badly literally cancel start again broadband tv landline hours wasted calls week far promise resolved march unacceptable
# unsatisfactory conv bt helpline elderly neighbours landline weeks rang times past week fault fixed recent operative refused tell going gave assurances fixed
# find new sits awardwinning cto exclusive interview live mwc watch
# british people synonymous telecoms business mission change that instead seen tech firm telco so bt upping game getting startups involved way
# grandad awaiting important hospital poor mobile signal live middle disgusting customer care shocked
# upsetting thing asked time things change nans mobile internet phone time promised happen bothered
# thing happened night times cut long hold periods got said repair monday previously told latest thursday priority vulnerability
# pay month find access sky channels past hours despite able access online appsfuckin rip
# time cut off trying help grandparents working cut time mins appalling
# prices going up looks like going find broadband provider month rise joke broadband guys tell with recommendations
# familiar story grandparents sticks phone week half told dealt grandad awaiting important hospitalnobody bothers let know changes made care vulnerable
# absolutely diabolical service vulnerable people living middle phone internet week half promised dates fix happened holding times mins cut off
# latest leadership bulletin out including feature values kudos recommended article working home template focusing important tasks read free
# hi graham sorry fault time taking fix estimates fix subject change dm account holder address including postcode account number track update this ian team
# loving mbps
# service serve up broadband landline lots lies update days service accurate progress reports forgottenbolney
# hi janet order good wondering new fttp install takeover old fttc line like standard wlt fttc persons need cancelled separately
# omnitel proud appointed direct partner covering west east south scotland today like celebrate years more bt btlocalbusiness supportlocal scotland connectivity
# close beginning g journey industry experimenting metaverselike experiences shown green planet good catch iain morris mwc
# receiving mail norton bt downloaded mac clicked devices tell phone pad protected need do thank anticipation
# shower shit brand values toilet soon mention naybody dealing compnaies sod luck reply days counting internet landline lots broken promises shite
# internet dropping morning annoying trying work
# hi guys copper line running house ex husbands getting fibre installed name existing line need cancel services wlt letter arrived installation today
# service nd time days wifi phone line ha nd home hub type b approx yrs old help
# thanks engineer says port cabinet disconnected connect new customer free ports allowed
# distinguished business leaders inaugural digital impact fellows welcome delighted team business research impact
# verify identity link click on
# bt disc solid purple light reset help issues upgrading this thank
# remove rt news tv services need russian propaganda stations uk tv
# idea consider blocking fairly notorious russianbacked websites whilst it infowar war too russiatoday putinwarcriminal
# open xr forum covers wide range participants applications new members includes info
# hi melissa sorry fault broadband dm account holder address including postcode account number check you ian team
# hey bt waiting restored internet weeks storm eunicei called day given clear times met single themi work home costing moneyif cost job taking legal action sort out
# hey bt waiting restored internet weeks storm eunicei called day given clear times met single themi work home costing moneyif cost job taking legal action sort out
# hey bt waiting restored internet weeks storm eunicei called day given clear times met single themi work home costing moneyif cost job taking legal action sort out
# hey bt waiting restored internet weeks storm eunicei called day given clear times met single themi work home costing moneyif cost job taking legal action sort out
# hey bt waiting restored internet weeks storm eunicei called day given clear times met single themi work home costing moneyif cost job taking legal action sort out
# hey bt waiting restored internet weeks storm eunicei called day given clear times met single themi work home costing moneyif cost job taking legal action sort out
# hey bt waiting restored internet weeks storm eunicei called day given clear times met single themi work home costing moneyif cost job taking legal action sort out
# hey bt week sure flown internet waiting restored internet weeks storm eunicei called day nothingi work home costing moneyif cost job taking legal action sort out
# hey bt waiting restored internet weeks storm eunicei called day given clear times met single themi work home costing moneyif cost job taking legal action sort out
# hey bt waiting restored internet weeks storm eunicei called day given clear times met single themi work home costing moneyif cost job taking legal action sort out
# hey bt waiting restored internet weeks storm eunicei called day given clear times met single themi work home costing moneyif cost job taking legal action sort out
# hey bt waiting restored internet weeks storm eunicei called day given clear times met single themi work home costing moneyif cost job taking legal action sort out
# hey bt waiting restored internet weeks storm eunicei called day given clear times met single themi work home costing moneyif cost job taking legal action sort out
# hey bt waiting restored internet weeks storm eunicei called day given clear times met single themi work home costing moneyif cost job taking legal action sort out
# hey bt waiting restored internet weeks storm eunicei called day given clear times met single themi work home costing moneyif cost job taking legal action sort out
# message sent
# nan
# Warning! Exception: object of type 'float' has no len() generated by the following text: 'nan'
# ok
# look records david wrote
# bill price agreed david said gonna right price agreed with said email manager says meeting said email email let
# working
# looks like right hand know left hands doing
# week happy customer said ring am yesterday sort problem moved meeting cancel meetings day utter joke bt
# echo said post great true partnerships evolving creating building profitable revenue streams
# long time fttp customers like drop voice landline broadband that
# thanks ellie unfortunately nearly weeks think answer good anymore spoken people sky help suggest interim solution end contract somebody reach discuss switching services thanx
# open xr forum covers wide range participants applications new members includes info
# hey phone broadband rd supposed fixed yesterday call text email restored discount lack service
# thank much managed yesterday fix thanks checking x
# thanks followed trouble shooting steps worked thanks getting though appreciate
# bit interested sizeable package costs month fact going renewal fact customer new customers package fraction pay going start shopping new provider
# bt tv box resets th march interfering recordings
# evening reception hear minister diversification horizon europe
# tweeted posted
# going tv box thinks today th shows set record showing failed record
# parents phonewifi days delayed repair days vulnerable way contact anyone look asap
# thought outage fixed night hope charging month
# broadband area ip norfolk streaming minutes ago lost connection rebooted router orange light tried bt smart hum code nc
# waiting minutes page load pay bill case months no taking direct debit
# communication bt sound like threat left new providers communication breath fresh air years bt customer beginning wonder it
# help internet speeds mbps troubleshooter says getting mbps box issue clearly is
# sorry clue online services provide interested online kind all need simplify peopleand melike telephone did forgotten use damn phone
# switched booked engineer told need despite phone socket called promised phone today arrange visit guess disappointed
# so latest screen choose like receive pin options given
# hi sorry work popped going sit tomorrow figure link let know
# following number conversations week emergencyalerts hopefully awareness campaign educate support
# use link motherinlaw id trying set up
# broadband yesterday today check service status landline
# elderly customer wishes set id manage account online far that proceed telephone number instructions great service
# cheeky devils putting bill month roughly figure from looking change provider bt
# broadband drop days reconnect minutes going months
# think main issue rt getting increasingly involved french elections
# available tv uk argument rt cut here bbc cut there wider reach former idea
# snap
# village telephone exchanges diesel generator backup keeps analog lines wifi hotspot use digital voice
# pleasure welcome evening help educate share message hope utd campaign ways manage online abuse educate players good online practice
# digital dont work power cuts dead cordless phones local exchanges back batteries analogue alive copper wires alarm systems elderly use too minl years council afford change
# yes dug battery portable radio contact outside world isolating experience landline phones removed
# surely ok
# annual global partner summit like congratulate award winners including year gps
# enjoyed visit week talked things online safety fantastic new hub action
# paying month mbs broadband guaranteed minimum mbs months felt like running like shit speed test getting mbs checked online changed plan mbs charging
# number find expand
# option send information private message
# digital voice transition fault online fault code ending
# fair tories labour shady links russian organised crime too gordon brown shriti vadera helped install russian spyware telecoms network operated covertly years gathering economic intelligence prosecuted
# options copper speeds good anyone wait comes available
# stop taking money twice month thank cutting internet x
# need help address think cabinet full getting broadband
# dm sent account details requested hours ago
# closed complaint input me resolved
# thank you
# day
# checked says signal excellent inconsistent recently happy about
# broadband rubbish today going on
# thanks now batteryelectrical portable digital fm radio anymore
# broadband connection
# trying sort landline nearly weeks impossible speak customer service finally transfer lose them want cancel way telephone knows
# digital line mean mobile signal
# power days roads blocked generators villageno gas canisters transmitters down analogue phone contact outside digital going option away council gave instructions fb clever mobile
# fixed thanks
# way reporting online telephone av
# report issue bt flagpole
# shall dm account number unsure checking eventually reduction arwen mention days time shall said send dm difficult track regular thing late
# probably reduce complaints power outages hour hold battery backup gone
# thank care
# time week storm arwen reduction appeared time elapsed contact tweet
# great partners supporting people ukraine past week thank removing roaming charges providing digitalinclusion support tweets information
# records showbased sms engineer visit st th nd month
# does respectfully ask good battery backup storm power outages lasted excess days taking mobile phone transmitters it need wifi hotspots existing generator backed exchanges
# noticed bill shown reduction tines service
# complaint ongoing november written ombudsman mp thanks offer bt clearly unable sort this
# bt failed provide broadband connection moved house november yearthey want charge month g connection instead totally disgraceful bt treat customers years
# good thanks david took hour sort cock ups bt hopefully sorted honest hard work swapping bt ee took min hold ee spoke lovely lady
# hate broadband rage advert stresses
# ok thanks sure gotten you
# giving realistic accurate sketch true soulmate
# wow rang getting quote able price match got quote apparently price match came new offer unbelievable marketing
# hi scott unhappy provider follow steps outlined complaints procedure problem resolved able adr scheme
# why upsetting time dealing bereavement difficult frontline team hopeless help lpa reference numbers photos passports shared financial institutions difficult help
# days broken internet engineer visits noone turned expected better
# making dealing bereavement parents difficult companies including demanding details lpa reference code enough processes procedures antiquated poor team help
# teachers careers staff working schools colleges meet apprentice find toms apprenticeship journey networks degree apprentice register
# did thank
# thanks email informs price rise half way contract stating improving things improving finances bad getting away prices
# absolutely customer service whatsoever loyal customer getting treated like crap
# read roject community lab hosted adastral park uses itrinegy software defined test networks assess impact nonideal fronthaul virtualized ran learn more mwc vran oran innovationmartlesham
# helloooooooi waiting
# thanks this way switch process sped working home deactivated march th sooner date help massively work
# olivia consumer price index increase ee employees r charged bet ee giving u salary increase alienate s thousands customers eu roaming charges day think kev everybody cut footloose
# well clearly state mini hub turned today uselessjust like service repair repair thmarch
# cheers
# mature audiences onlykinda band
# useless
# shite complete utter load bollocks ffs
# day power cut recent storms ukpn issued text number report power cuts updates number looking ee bill charged premium rate right surely like charging customers dial
# hello stated clearly december took contract ie ee your bill increase april ok renew contract childrens contracts come end eu roaming kevin bacon livid byebyeee
# vodafone
# complain ee told renew end contract childrens contracts taking mickey day roaming charge eu
# hi upgraded simo got shiny new iphone pro thank you question received new sim card pack need activated use existing sim
# prices increasing hid small print great news utility costs ee
# day works hell cocked upgrade th time sending wrong phone wrong contract right till wrong gets posted arse tries use bank card usa card cancelled skip week
# best customer service long time thank sorting issue out truly appreciate it
# g signal poor constantly wish hadnt upgraded better deal new phone
# know hassle it calls calls haggle better deal frustrating times
# price increase mobile contract customer offer given broadband ee apply discount brings mobile bill now yeah think time found new mobile provider
# love hear feedback this paying extra pound extra acceptable hide customer service got lot worse people want answers commented paying extra month unacceptable
# hold like minutes playing nice songs
# yes leeds djing temple arches th march parallelg apply tickets
# accessibility category baftagames
# called twice hung waiting mins recently bought samsung s ultra contract advise claim samsung pro buds aware claimed samsung ee samsung provide indication
# confirm roaming available contract taken october
# signed contract telling waited hours saved money despite told kick following march
# making switch picked decent sim deal s ultra months asking fix problem losing voicemail upgrading promised backs tried payg check service speeds amazing need wifi calling
# embarrassing price increase fellas seen excuses given lol
# honesty helen gutted too loyal ee good me
# hi helen thanks message yes spoken team fact deal trying match mentioned team member said pac code able beat that given offers else shame
# whooaa from
# robbing bastards
# sort things stop able unable upgrade
# thanks thanks
# frustrating best deal existing customers offered new customers benefits higher bill staying ee
# notification bill month check dates pay system down
# exactly thing cbaaaa
# test engineer paying visit saturday thanks support david
# signal g wife g signal
# reward loyalty anymore forget paying higher price use uswitch inevitably match deals on
# number send spam texts to
# admit paid bill mainly ee account
# lost household loyal customers total nearly years greed advise anybody thinking moving so
# thanks lot feel inflation fair price hike god knows disgraceful behaviour greed running contract moving company values years custom dick turpin common decency wear mask
# look monthly contract upgrade costs contract prices far higher network data phone absolutely astronomical thought want existing customers good deals
# signal burgess hill bars g getting speed buffering
# friends ukraine way ukrainian phone number ported uk ee account pay bill help stay online
# join darlington sector based work academy programme week course guaranteed interview starting am march dolphin centre darlington ask work coach details book place darlingtonjobs dtvswap
# little things it
# yes acknowledgement
# send yes mobile ee
# lol clearly aware
# update internet outage pl area yet
# looked page trying find store website clear want post it person
# hey great finally implement policy customers affected domestic abuse corporateaccountability corporateresponsibility dosomething victimblaming survivorshaming metoo coercivecontrol financialabuse domesticabuse day
# justify
# ee bring roaming charges travelling european countries irish news
# reception teeside terrible
# annoyed sim contract decided switch phone years want pay contract
# delivered text number
# emailed mobile contract increase month bill going up got email well
# hi john thanks awesome efforts donate bt childrens fund emergency charity partner unicef
# thanks peter
# let know price hike joined contract month ago rude
# help playstation order placed yesterday told order placed hold delivery date dpd assumed despatch day delivery promised email
# amazing money grab inc raising prices cpi point cpi highest years surprised customer revolt
# maybe help
# customer advisor based shrewsburyjobs click apply shropshirejobs retailjobs
# know well taking piss ee
# switched tesco mobile month changes charges years contract coverage as use o network ee ee years definitely right thing leaving ee
# roaming charges coming live north ireland charges going border republic ireland
# planning trading old phone process store
# yet considering options change networks
# thanks peter fair payasyougo airport then tried set ee account manage things phone register international mobile number pain travel worries
# got new contract love new seeing saved contract hey hum
# tested ee speed connection g home mb regular broadband g
# managed chat sorted thanks
# hi paul unhappy provider follow steps outlined complaints procedure problem resolved able adr scheme
# upgrade select phones says it looks like suitable plans available device phone
# frustrating cant change contract money change you
# worst o try
# thank alert thank day delivery
# raising prices
# literally talk hours horrific experiences vm years however bloody legends including giving months broadband free took us recent house move
# ouch adsl speeds
# hi travelling italy tomorrow roam use data additional step take let know thanks
# hi michael yes spoke match deals virgin o vodafone voxi gifgaf
# price rise protect vulnerable customers suffering financial hardship
# impressive
# think engineer help look like line needs checking speed test shows mbps download moment
# finally managed pay trying payments debit card bank locked account thanks lot soon exee customer
# sorry olivia meant yousomeone word scheduling team wicklow changing hours notice processing annual leave requests tia
# hi yes have managed check night site stopped working maintenance access my ee again daily thing
# taking piss drop email telling bills going up contract cost agreed signed too
# thinking moving ee added cpi figure thought bad enough received tangible benefit price rises far
# nan
# Warning! Exception: object of type 'float' has no len() generated by the following text: 'nan'
# love outfit
# actually going cost living right now got notice phone bill going cpi additional fun
# handsome
# yep spent hours trying connect me ended calling myself got told return start process actual system place unsealed new devices likely delayed new phone weeks
# yes specifically asked getting contract told applied following march days buying contract
# network joke
# explain called latest technology understand fibre optic broadband assisted g connection
# shame jimmy like consider contract up shout happy help answer questions joining liz
# disgraceful leaving ee earliest opportunity
# worth worst all provider coverage area no choice
# hey dmd details speed darlington slower tortoise leg chains happy person moment speeds separate devices separate sims
# thanks email price increase guess increased months timetoleave
# disgraceful customer singled contract certain price able increase price pay overheads second time months price increased gone month start contract
# try north scotland thats bloody sure signals crap end throat cut
# text says putting bill end march cpi rise plus justification please
# unfortunately stuck year will ee opportunity line pockets people struggling most thanks replying shame ee guess embarrassed
# using cpi linked great doubling rate course year paying equivalent additional months tariff
# thank behalf customers nearly rise current contracts todays climate exactly daylightrobbery noloyalty
# know time raising bills things differently here know jimmy come join liz
# wow wants increase prices living different planet
# wow joined years find bill increasing remember contracts meant locked price duration roll years leave
# happy contract price increased service bad happy megan think straight unhappy
# absolutely shocking think acceptable pay service signing contract regardless farce agree new contract looked elsewhere
# well fingers crossed simple infuriating automated text bot helping either
# email informing tariff increasing effectively twice rate inflation tariff will therefore going elsewhere
# contract price increase ridiculous people agree price m expect paying year contract thieves
# unimpressed increasing monthly plan month signed new contract
# latest price rise obscene wait leave end contract
# know going internet area minute driving nuts stream night speeds today got find deal is
# disappointed need change network ee remain competitive networks
# hi thanks respond fair lot pay bill speak customer service thank explaining me sound like karen
# nearly
# aaaaaaaay thanks buzzing
# follow fellow liverpool fan lol
# frustrating leave tue office mobile datainternet kick home problems postcode sk today
# mate power bar uses regularly shame needed recalled coz better freebies ee outside perks plans apple music etc days
# it daaaance
# hi parents signal issues ta postcode area weeks now going issues weeks thanks
# guys good hype be eg open air platform baker st data bus kingston slow data visiting friend epsom data bad web site freezes boost sales thinks
# perfect thank worries reply night owl normally send wait till day
# fucking hiking price increase
# lucky
# great thoughtful thoughts ukraine
# hi marc work birchwood office trying organise donations sent over company better donating privately cheers
# thanks ee way rip customers increasing contracts time salarys risen costs gone raise prices nearly not shame
# fantastic email inflated increase phone bill pm wished customer service phone service years warranted kind increase month energy bills going april lovely know customers heart
# raise price
# excellent
# bill going extra
# paying roaming charges asking gb customers
# going looking internet provider asylum seeking family got special deals
# year sept remember exact date pay calls know pound
# ask co wicklow team mindful changing peoples shifts short notice work month cancelled appointments meals worktolivenotlivetowork
# k think pushing awesome k
# nice helping people displaced ukraineinvasion stand pure evil dictator putin kills innocent people istandwithukriane
# hope ones recalled years ago marcy boy
# hi dm talk historic default account like resolve thanks
# believe happened
# set send reminder special appleevent starts march pm reply end opt out
# thought k modem impressive time
# bloody impressive little thing carry pocket
# bonkers speed
# long got pro got out crazy speeds
# hi casey looking add new card update expired registered card thanks
# seriously impressed todays g speed ee
# current contract expire week price match providers cheaper tariffs data offered rivals
# mbs minimum guaranteed
# thanks
# genuine guy shaver know stop neck shaving looks like hand air visual phone believe it
# check dms contact weeks this
# need assistance phone signal past day now
# doubt paid greedy bastards introducing roaming feessomething said do
# got fleeced mate still jealous
# heading leeds st time th march play exclusive set temples arches parallel g going ultimate live music experience trust apply tickets parallelg
# kudos
# phone contracts simple got random message today reaching spending cap today phone days know spend cap
# paid phone end jan paying sim told going find easy way change sim desk crazy sim only
# getting fed seeing ad shafting thousands others

# %%
data.head()
# Out:
#                                                 text  \
# 0  @bt_uk @mikeburnieactor i am having the same p...
# 1  @henrystewartdam @theresaregli @mcdonalds @yal...
# 2  why is does the tv listings in my @bt_uk box a...
# 3  @bill626 @bt_uk try setting it to record quest...
# 4  @bill626 @bt_uk i figured it out it will not r...
#
#                                          clean2_text  label  \
# 0  problem online support booked engineer likely end     -1
# 1                                               wait     -1
# 2  tv listings box planner actual tv think friday...     -1
# 3       try setting record quest midnight tells goes      1
# 4  figured record stuff midnight recording snooke...     -1
#
#                                             keywords
# 0  [problem online support, online support booked...
# 1                                             [wait]
# 2  [lost plot issue, listings box planner, box pl...
# 3  [setting record quest, record quest midnight, ...
# 4  [figured record stuff, record stuff midnight, ...
